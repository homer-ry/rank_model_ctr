# %%
import pickle
import pandas as pd

# %%
def to_df(file_path):
    with open(file_path, 'r') as fin:
        df = {}
        i = 0
        for line in fin:
            df[i] = eval(line)
            i += 1
        df = pd.DataFrame.from_dict(df, orient='index')
        return df

# %% [markdown]
# # 1.用户样本表：从JSON转换到DF，压缩PB存储
# * unixReviewTime    1689188
# * reviewerID        1689188
# * overall           1689188
# * reviewText        1689188
# * asin              1689188
# * helpful           1689188
# * summary           1689188
# * reviewTime        1689188
# * reviewerName      1664458

# %%
reviews_df = to_df('../raw_data/reviews_Electronics_5.json')
with open('../raw_data/reviews.pkl', 'wb') as f:
    pickle.dump(reviews_df, f, pickle.HIGHEST_PROTOCOL)

# %%
reviews_df.count()
# Out:
# unixReviewTime    1689188
# reviewerID        1689188
# overall           1689188
# reviewText        1689188
# asin              1689188
# helpful           1689188
# summary           1689188
# reviewTime        1689188
# reviewerName      1664458
# dtype: int64

# %%
reviews_df[:5]
# Out:
#    unixReviewTime      reviewerID  overall  \
# 0      1370131200   AO94DHGC771SJ      5.0
# 1      1290643200   AMO214LNFCEI4      1.0
# 2      1283990400  A3N7T0DY83Y4IG      3.0
# 3      1290556800  A1H8PY3QHMQQA0      2.0
# 4      1317254400  A24EV6RXELQZ63      1.0
#
#                                           reviewText        asin   helpful  \
# 0  We got this GPS for my husband who is an (OTR)...  0528881469    [0, 0]
# 1  I'm a professional OTR truck driver, and I bou...  0528881469  [12, 15]
# 2  Well, what can I say.  I've had this unit in m...  0528881469  [43, 45]
# 3  Not going to write a long review, even thought...  0528881469   [9, 10]
# 4  I've had mine for a year and here's what we go...  0528881469    [0, 0]
#
#                                   summary   reviewTime  \
# 0                         Gotta have GPS!   06 2, 2013
# 1                       Very Disappointed  11 25, 2010
# 2                          1st impression   09 9, 2010
# 3                 Great grafics, POOR GPS  11 24, 2010
# 4  Major issues, only excuses for support  09 29, 2011
#
#                reviewerName
# 0                   amazdnu
# 1           Amazon Customer
# 2             C. A. Freeman
# 3  Dave M. Shaw "mack dave"
# 4               Wayne Smith

# %% [markdown]
# # 2.商品元信息表：从JSON转换到DF，压缩PB存储
# * asin           63001
# * imUrl          62957
# * description    61286
# * categories     63001
# * title          61820
# * related        60682
# * price          58969
# * salesRank      21293
# * brand          29751

# %%
meta_df = to_df('../raw_data/meta_Electronics.json')
meta_df = meta_df[meta_df['asin'].isin(reviews_df['asin'].unique())]
meta_df = meta_df.reset_index(drop=True)
with open('../raw_data/meta.pkl', 'wb') as f:
      pickle.dump(meta_df, f, pickle.HIGHEST_PROTOCOL)

# %%
meta_df.count()
# Out:
# asin           63001
# imUrl          62957
# description    61286
# categories     63001
# title          61820
# related        60682
# price          58969
# salesRank      21293
# brand          29751
# dtype: int64

# %%
meta_df[:5]
# Out:
#          asin                                              imUrl  \
# 0  0528881469  http://ecx.images-amazon.com/images/I/51FnRkJq...
# 1  0594451647  http://ecx.images-amazon.com/images/I/51RjSETO...
# 2  0594481813  http://ecx.images-amazon.com/images/I/41K7ymN5...
# 3  0972683275  http://ecx.images-amazon.com/images/I/41hYJ9Mw...
# 4  1400532620  http://ecx.images-amazon.com/images/I/519ca3cu...
#
#                                          description  \
# 0  Like its award-winning predecessor, the Intell...
# 1  HDTV Adapter Kit for NOOK HD and NOOK HD+\nThi...
# 2  Power up your device with this Barnes &amp; No...
# 3  The VideoSecu TV mount is a mounting solution ...
# 4  Barnes & Noble Nook eReader - no 3GMeet nook. ...
#
#                                           categories  \
# 0  [[Electronics, GPS & Navigation, Vehicle GPS, ...
# 1  [[Electronics, Computers & Accessories, Touch ...
# 2  [[Electronics, eBook Readers & Accessories, Po...
# 3  [[Electronics, Accessories & Supplies, Audio &...
# 4       [[Electronics, eBook Readers & Accessories]]
#
#                                                title  \
# 0  Rand McNally 528881469 7-inch Intelliroute TND...
# 1  Barnes &amp; Noble HDTV Adapter Kit for NOOK H...
# 2   Barnes &amp; Noble OV/HB-ADP Universal Power Kit
# 3  VideoSecu 24&quot; Long Arm TV Wall Mount Low ...
# 4            Barnes &amp; Noble Nook eReader - no 3G
#
#                                              related   price  \
# 0  {'also_viewed': ['B006ZOI9OY', 'B00C7FKT2A', '...  299.99
# 1  {'buy_after_viewing': ['0594481813', '05944819...   49.95
# 2  {'buy_after_viewing': ['0594481902', 'B00AZRHY...   19.65
# 3  {'buy_after_viewing': ['B000WYVBR0', 'B001GTT0...   29.99
# 4  {'buy_after_viewing': ['140053271X', 'B007HCCN...   74.95
#
#                 salesRank               brand
# 0                     NaN                 NaN
# 1                     NaN                 NaN
# 2                     NaN  Barnes &amp; Noble
# 3                      {}           VideoSecu
# 4  {'Electronics': 23071}  Barnes &amp; Noble
